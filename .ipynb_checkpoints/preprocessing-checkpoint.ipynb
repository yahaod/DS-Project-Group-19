# %%
import pandas as pd
df = pd.read_excel('Data files for UniMelb Project - data until 2021/Sales Data.xlsx')
df
# Out:
#         Sold-To Party                         Name 1      Material  \
# 0                9477           SA Water Corporation  ALUSUL08-200
# 1               11611                Trility Pty Ltd  ALUSUL08-200
# 2                9477           SA Water Corporation  ALUSUL08-200
# 3                9477           SA Water Corporation  ALUSUL08-200
# 4                9477           SA Water Corporation  ALUSUL08-200
# ...               ...                            ...           ...
# 228427           7650            Bartter Enterprises    SODHYP13-B
# 228428           6190  YMCA Singleton Swim & Fitness    SODHYP13-B
# 228429           8029        Paper Australia Pty Ltd    SODHYP13-B
# 228430           7650            Bartter Enterprises    SODHYP13-B
# 228431           7650            Bartter Enterprises    SODHYP13-B
#
#                                 Description Delivery Date  Confirmed Quantity  \
# 0       ALUMINIUM SULFATE LIQUID, 200L drum    2021-02-01                 8.0
# ...

# %%
df = df.drop(df[df['Confirmed Quantity']==0].index)

# %%
df['Quantity in L'] = 'undefined'

# %%
df.head()
# Out:
#    Sold-To Party                Name 1      Material  \
# 0           9477  SA Water Corporation  ALUSUL08-200
# 1          11611       Trility Pty Ltd  ALUSUL08-200
# 2           9477  SA Water Corporation  ALUSUL08-200
# 3           9477  SA Water Corporation  ALUSUL08-200
# 4           9477  SA Water Corporation  ALUSUL08-200
#
#                            Description Delivery Date  Confirmed Quantity  \
# 0  ALUMINIUM SULFATE LIQUID, 200L drum    2021-02-01                 8.0
# 1  ALUMINIUM SULFATE LIQUID, 200L drum    2020-12-21                 4.0
# 2  ALUMINIUM SULFATE LIQUID, 200L drum    2020-12-18                 8.0
# 3  ALUMINIUM SULFATE LIQUID, 200L drum    2020-11-12                 8.0
# 4  ALUMINIUM SULFATE LIQUID, 200L drum    2020-11-12                 6.0
#
#   Sales Unit Plant Ship-To Party Ship-to party name 1 Quantity in L
# 0        DRM  S106         64679          WIRRINA WTP     undefined
# 1        DRM  S106         57395        Birdwood WWTP     undefined
# ...

# %%
df.loc[df['Sales Unit']=='KG', 'Confirmed Quantity'] = df['Confirmed Quantity']/1000
df.loc[df['Sales Unit']=='KG', 'Sales Unit'] = 'TO'

# %%
df.loc[df['Sales Unit']=='DRM', 'Quantity in L'] = df['Confirmed Quantity']*200
df.loc[df['Sales Unit']=='BOX', 'Quantity in L'] = df['Confirmed Quantity']*1000
df.loc[df['Sales Unit']=='PLY', 'Quantity in L'] = df['Confirmed Quantity']*15
df.loc[df['Sales Unit']=='IBC', 'Quantity in L'] = df['Confirmed Quantity']*1000
df.loc[df['Sales Unit']=='KL', 'Quantity in L'] = df['Confirmed Quantity']*1000
df.loc[df['Sales Unit']=='L', 'Quantity in L'] = df['Confirmed Quantity']*1
df.loc[(df['Sales Unit']=='TO') & (df['Material'].str.contains('ALUSUL08')), 'Quantity in L'] = df['Confirmed Quantity']*(1000/1.31)
df.loc[(df['Sales Unit']=='TO') & (df['Material'].str.contains('MHL')), 'Quantity in L'] = df['Confirmed Quantity']*(1000/1.5)
df.loc[(df['Sales Unit']=='TO') & (df['Material'].str.contains('PAC10')), 'Quantity in L'] = df['Confirmed Quantity']*(1000/1.19)
df.loc[(df['Sales Unit']=='TO') & (df['Material'].str.contains('PAC23')), 'Quantity in L'] = df['Confirmed Quantity']*(1000/1.34)
df.loc[(df['Sales Unit']=='TO') & (df['Material'].str.contains('SODHYP')), 'Quantity in L'] = df['Confirmed Quantity']*(1000/1.2)

# %%
df
# Out:
#         Sold-To Party                         Name 1      Material  \
# 0                9477           SA Water Corporation  ALUSUL08-200
# 1               11611                Trility Pty Ltd  ALUSUL08-200
# 2                9477           SA Water Corporation  ALUSUL08-200
# 3                9477           SA Water Corporation  ALUSUL08-200
# 4                9477           SA Water Corporation  ALUSUL08-200
# ...               ...                            ...           ...
# 228427           7650            Bartter Enterprises    SODHYP13-B
# 228428           6190  YMCA Singleton Swim & Fitness    SODHYP13-B
# 228429           8029        Paper Australia Pty Ltd    SODHYP13-B
# 228430           7650            Bartter Enterprises    SODHYP13-B
# 228431           7650            Bartter Enterprises    SODHYP13-B
#
#                                 Description Delivery Date  Confirmed Quantity  \
# 0       ALUMINIUM SULFATE LIQUID, 200L drum    2021-02-01                 8.0
# ...

# %%
df[df['Sales Unit']=='TO']
# Out:
#         Sold-To Party               Name 1       Material  \
# 80              52553  LION MINING PTY LTD  ALUSUL08-1000
# 81              58171               Sumich  ALUSUL08-1000
# 83              52553  LION MINING PTY LTD  ALUSUL08-1000
# 84              58171               Sumich  ALUSUL08-1000
# 85              58171               Sumich  ALUSUL08-1000
# ...               ...                  ...            ...
# 226483           1699         Visy Paper 2     SODHYP13-B
# 226821           1699         Visy Paper 2     SODHYP13-B
# 227445           1699         Visy Paper 2     SODHYP13-B
# 227796           1699         Visy Paper 2     SODHYP13-B
# 228194           7743  Nuplex Pulp & Paper     SODHYP13-B
#
#                                      Description Delivery Date  \
# 80      ALUMINIUM SULFATE LIQUID 1000L (1310 kg)    2021-04-14
# 81      ALUMINIUM SULFATE LIQUID 1000L (1310 kg)    2021-04-07
# 83      ALUMINIUM SULFATE LIQUID 1000L (1310 kg)    2021-03-24
# ...

# %%
df[df['Quantity in L']=='undefined']
# Out:
#        Sold-To Party                             Name 1       Material  \
# 35828          64632     Booth Transport - Strathmerton   MHL-22.5PAIL
# 35829          64632     Booth Transport - Strathmerton   MHL-22.5PAIL
# 35830          97122                Edge Complete Water   MHL-22.5PAIL
# 46538          53137  Robson Civil Projects Pty Limited       PAC23-15
# 46539          53137  Robson Civil Projects Pty Limited       PAC23-15
# ...              ...                                ...            ...
# 89767          65160         The Pool Merchant - Darwin  SODHYP12PM-15
# 89768          65160         The Pool Merchant - Darwin  SODHYP12PM-15
# 89769          65160         The Pool Merchant - Darwin  SODHYP12PM-15
# 89770          65160         The Pool Merchant - Darwin  SODHYP12PM-15
# 89771          65160         The Pool Merchant - Darwin  SODHYP12PM-15
#
#                                    Description Delivery Date  \
# ...
