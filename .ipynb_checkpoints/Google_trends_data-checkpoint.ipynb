# %%
conda install -c conda-forge pytrends
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US')

kw_list = ["Ixom", "Orica Chemicals", "Coogee Chemicals", "Cleveland Bay"]
pytrends.build_payload(kw_list, cat=12, timeframe='2010-01-01 2015-03-01', geo='AU', gprop='')
data_before_2015 = pytrends.interest_over_time()
pytrends.build_payload(kw_list, cat=12, timeframe='2015-03-01 2022-04-01', geo='AU', gprop='')
data_after_2015 = pytrends.interest_over_time()

# %%
mean_before = round(data_before_2015.mean(), 2)
mean_after = round(data_after_2015.mean(), 2)
for kw in kw_list:
    print(kw + ":" + str(mean_before[kw]))
# Out:
# Ixom:0.08
# Orica Chemicals:8.41
# Coogee Chemicals:7.01
# Cleveland Bay:3.56

# %%
for kw in kw_list:
    print(kw + ":" + str(mean_after[kw]))
# Out:
# Ixom:33.59
# Orica Chemicals:8.0
# Coogee Chemicals:23.58
# Cleveland Bay:12.13

# %%
data_after_2015
# Out:
#             Ixom  Orica Chemicals  Coogee Chemicals  Cleveland Bay  isPartial
# date
# 2015-03-01    27                9                29             18      False
# 2015-04-01    62               57                10              0      False
# 2015-05-01    29               62                20              0      False
# 2015-06-01    30                0                31              0      False
# 2015-07-01    29               27                29             19      False
# ...          ...              ...               ...            ...        ...
# 2021-12-01    27                0                18              9      False
# 2022-01-01    33                8                42             16      False
# 2022-02-01    29                0                39              9      False
# 2022-03-01    49                0                17             32      False
# 2022-04-01    48               16                16             32       True
#
# [86 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(data_after_2015)
plt.legend(kw_list)
plt.show()

# %%
focus = ["Ixom", "Cleveland Bay"]
plt.plot(data_after_2015[focus])
plt.legend(focus)
plt.show()

# %%
region = pytrends.interest_by_region(resolution='REGION', inc_low_vol=True, inc_geo_code=False)
region
# Out:
#                               Ixom  Orica Chemicals  Coogee Chemicals  \
# geoName
# Australian Capital Territory     0                0                 0
# New South Wales                 64               13                17
# Northern Territory               0                0                 0
# Queensland                      16                0                28
# South Australia                100                0                 0
# Tasmania                         0                0                 0
# Victoria                        72               14                12
# Western Australia               14                0                86
#
#                               Cleveland Bay
# geoName
# Australian Capital Territory              0
# New South Wales                           6
# Northern Territory                        0
# Queensland                               56
# South Australia                           0
# Tasmania                                  0
# Victoria                                  2
# Western Australia                         0

# %%
region.plot(kind = 'bar')
plt.show()

# %%
pytrends.related_queries() # related queries in last 7 years
# Out:
# {'Ixom': {'top':              query  value
#   0            orica    100
#   1   ixom chemicals     57
#   2  orica chemicals     23
#   3      ixom botany     22,
#   'rising':              query    value
#   0            orica  2100750
#   1   ixom chemicals  1205700
#   2  orica chemicals   477050
#   3      ixom botany   454300},
#  'Orica Chemicals': {'top':   query  value
#   0  ixom    100,
#   'rising':   query    value
#   0  ixom  2365300},
#  'Coogee Chemicals': {'top': None, 'rising': None},
#  'Cleveland Bay': {'top':           query  value
#   0  first choice    100,
#   'rising':           query  value
#   0  first choice    850}}
